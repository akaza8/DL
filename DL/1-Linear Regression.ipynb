# %% [markdown]
# 1-Linear Regression by using Deep Learning

# %%
import numpy as np
import pandas as pd
import io

df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/DL DATASETS/BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
from sklearn.model_selection import train_test_split

X = df.loc[:, df.columns != 'medv']
y = df.loc[:, df.columns == 'medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
y_test.shape
# Out:
# (152, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming you have already split your data into training and testing sets (X_train, X_test, y_train, y_test)

# Linear Regression model
regressor = LinearRegression()

# Fitting the model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predictions on the test set
y_pred = regressor.predict(X_test)

# Calculating mean squared error and mean absolute error
mse_lr = mean_squared_error(y_test, y_pred)
mae_lr = mean_absolute_error(y_test, y_pred)

print('Mean squared error on test data: ', mse_lr)
print('Mean absolute error on test data: ', mae_lr)
# Out:
# Mean squared error on test data:  28.405854810508146
# Mean absolute error on test data:  3.6913626771162664

# %%
from sklearn.preprocessing import StandardScaler
mms = StandardScaler()
mms.fit(X_train)
X_train = mms.transform(X_train)
X_test = mms.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(128, input_shape=(13, ), activation='relu', name='dense_1'))
model.add(Dense(64, activation='relu', name='dense_2'))
model.add(Dense(32, activation='relu', name='dense_3'))
model.add(Dense(16, activation='relu', name='dense_4'))
model.add(Dense(1, activation='relu', name='dense_output'))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 128)               1792
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_output (Dense)        (None, 1)                 17
#
# =================================================================
# Total params: 12673 (49.50 KB)
# Trainable params: 12673 (49.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.05, verbose = 1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 25ms/step - loss: 591.7358 - mae: 22.4849 - val_loss: 609.3087 - val_mae: 22.7793
# Epoch 2/100
# 11/11 [==============================] - 0s 5ms/step - loss: 551.4717 - mae: 21.5260 - val_loss: 548.1753 - val_mae: 21.4153
# Epoch 3/100
# 11/11 [==============================] - 0s 5ms/step - loss: 467.5913 - mae: 19.4014 - val_loss: 410.2949 - val_mae: 17.9710
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 296.5269 - mae: 14.8329 - val_loss: 177.9686 - val_mae: 10.8502
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 110.3495 - mae: 8.3010 - val_loss: 46.1608 - val_mae: 5.2180
# Epoch 6/100
# 11/11 [==============================] - 0s 7ms/step - loss: 57.5901 - mae: 5.7306 - val_loss: 30.8476 - val_mae: 4.7709
# Epoch 7/100
# 11/11 [==============================] - 0s 5ms/step - loss: 36.2615 - mae: 4.3489 - val_loss: 25.7109 - val_mae: 4.2726
# Epoch 8/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.0803 - mae: 3.7454 - val_loss: 16.8664 - val_mae: 3.4527
# Epoch 9/100
# 11/11 [==============================] - 0s 5ms/step - loss: 23.7126 - mae: 3.5750 - val_loss: 14.5534 - val_mae: 3.1318
# Epoch 10/100
# 11/11 [==============================] - 0s 5ms/step - loss: 21.1196 - mae: 3.2952 - val_loss: 13.4028 - val_mae: 3.0077
# Epoch 11/100
# 11/11 [==============================] - 0s 7ms/step - loss: 19.8900 - mae: 3.2674 - val_loss: 12.0679 - val_mae: 2.9897
# Epoch 12/100
# 11/11 [==============================] - 0s 6ms/step - loss: 18.2222 - mae: 3.0905 - val_loss: 11.4558 - val_mae: 2.8119
# Epoch 13/100
# 11/11 [==============================] - 0s 6ms/step - loss: 17.0944 - mae: 2.9638 - val_loss: 10.5848 - val_mae: 2.8164
# Epoch 14/100
# 11/11 [==============================] - 0s 7ms/step - loss: 16.3237 - mae: 2.9290 - val_loss: 9.7469 - val_mae: 2.6977
# Epoch 15/100
# 11/11 [==============================] - 0s 5ms/step - loss: 15.2561 - mae: 2.8136 - val_loss: 9.2051 - val_mae: 2.6055
# Epoch 16/100
# 11/11 [==============================] - 0s 5ms/step - loss: 14.5326 - mae: 2.7543 - val_loss: 8.6717 - val_mae: 2.5111
# Epoch 17/100
# 11/11 [==============================] - 0s 5ms/step - loss: 14.1465 - mae: 2.6902 - val_loss: 8.2666 - val_mae: 2.4221
# Epoch 18/100
# 11/11 [==============================] - 0s 5ms/step - loss: 13.4839 - mae: 2.6597 - val_loss: 8.1310 - val_mae: 2.4383
# Epoch 19/100
# 11/11 [==============================] - 0s 6ms/step - loss: 12.8939 - mae: 2.5552 - val_loss: 7.8477 - val_mae: 2.3840
# Epoch 20/100
# 11/11 [==============================] - 0s 5ms/step - loss: 12.3653 - mae: 2.5479 - val_loss: 7.9975 - val_mae: 2.4673
# Epoch 21/100
# 11/11 [==============================] - 0s 6ms/step - loss: 12.4092 - mae: 2.4911 - val_loss: 7.7915 - val_mae: 2.4489
# Epoch 22/100
# 11/11 [==============================] - 0s 6ms/step - loss: 11.6367 - mae: 2.4739 - val_loss: 8.0146 - val_mae: 2.4617
# Epoch 23/100
# 11/11 [==============================] - 0s 6ms/step - loss: 11.2232 - mae: 2.4211 - val_loss: 8.2422 - val_mae: 2.4888
# Epoch 24/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.9186 - mae: 2.3738 - val_loss: 8.0894 - val_mae: 2.4265
# Epoch 25/100
# 11/11 [==============================] - 0s 7ms/step - loss: 10.7600 - mae: 2.3521 - val_loss: 8.0787 - val_mae: 2.4092
# Epoch 26/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.4174 - mae: 2.3250 - val_loss: 8.3697 - val_mae: 2.4304
# Epoch 27/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.3276 - mae: 2.3308 - val_loss: 8.3476 - val_mae: 2.4347
# Epoch 28/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.0700 - mae: 2.3011 - val_loss: 8.3661 - val_mae: 2.4004
# Epoch 29/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.1789 - mae: 2.2438 - val_loss: 8.4092 - val_mae: 2.3757
# Epoch 30/100
# 11/11 [==============================] - 0s 6ms/step - loss: 9.6319 - mae: 2.2322 - val_loss: 9.8168 - val_mae: 2.5223
# Epoch 31/100
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4768 - mae: 2.1932 - val_loss: 8.0893 - val_mae: 2.3098
# Epoch 32/100
# 11/11 [==============================] - 0s 6ms/step - loss: 9.4196 - mae: 2.1850 - val_loss: 9.5134 - val_mae: 2.5002
# Epoch 33/100
# 11/11 [==============================] - 0s 6ms/step - loss: 9.2816 - mae: 2.1597 - val_loss: 7.9694 - val_mae: 2.2528
# Epoch 34/100
# 11/11 [==============================] - 0s 5ms/step - loss: 9.0248 - mae: 2.1326 - val_loss: 9.9313 - val_mae: 2.4818
# Epoch 35/100
# 11/11 [==============================] - 0s 6ms/step - loss: 9.1091 - mae: 2.1598 - val_loss: 8.5964 - val_mae: 2.3000
# Epoch 36/100
# 11/11 [==============================] - 0s 7ms/step - loss: 8.8722 - mae: 2.1234 - val_loss: 10.8153 - val_mae: 2.5020
# Epoch 37/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.9651 - mae: 2.1406 - val_loss: 8.1533 - val_mae: 2.2095
# Epoch 38/100
# 11/11 [==============================] - 0s 6ms/step - loss: 8.7319 - mae: 2.1032 - val_loss: 10.7983 - val_mae: 2.4452
# Epoch 39/100
# 11/11 [==============================] - 0s 6ms/step - loss: 8.5845 - mae: 2.0701 - val_loss: 8.8195 - val_mae: 2.2472
# Epoch 40/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.2492 - mae: 2.0610 - val_loss: 10.0100 - val_mae: 2.3611
# Epoch 41/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1796 - mae: 2.0296 - val_loss: 9.0769 - val_mae: 2.2540
# Epoch 42/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.2312 - mae: 2.0365 - val_loss: 10.7168 - val_mae: 2.4436
# Epoch 43/100
# 11/11 [==============================] - 0s 7ms/step - loss: 8.0752 - mae: 2.0310 - val_loss: 8.5994 - val_mae: 2.2020
# Epoch 44/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1491 - mae: 1.9932 - val_loss: 10.8843 - val_mae: 2.4616
# Epoch 45/100
# 11/11 [==============================] - 0s 6ms/step - loss: 7.8065 - mae: 1.9989 - val_loss: 9.3754 - val_mae: 2.2159
# Epoch 46/100
# 11/11 [==============================] - 0s 6ms/step - loss: 7.7692 - mae: 1.9677 - val_loss: 10.3402 - val_mae: 2.3525
# Epoch 47/100
# 11/11 [==============================] - 0s 6ms/step - loss: 7.6270 - mae: 1.9945 - val_loss: 9.9929 - val_mae: 2.2962
# Epoch 48/100
# 11/11 [==============================] - 0s 5ms/step - loss: 7.9665 - mae: 1.9765 - val_loss: 12.6484 - val_mae: 2.6331
# Epoch 49/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.0644 - mae: 2.1116 - val_loss: 8.9181 - val_mae: 2.3750
# Epoch 50/100
# 11/11 [==============================] - 0s 6ms/step - loss: 7.6961 - mae: 2.0030 - val_loss: 11.4802 - val_mae: 2.4318
# Epoch 51/100
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7054 - mae: 1.9601 - val_loss: 9.3262 - val_mae: 2.2308
# Epoch 52/100
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4047 - mae: 1.9514 - val_loss: 11.1447 - val_mae: 2.3689
# Epoch 53/100
# 11/11 [==============================] - 0s 5ms/step - loss: 7.1009 - mae: 1.9293 - val_loss: 9.9567 - val_mae: 2.2094
# Epoch 54/100
# 11/11 [==============================] - 0s 6ms/step - loss: 6.9172 - mae: 1.8871 - val_loss: 10.4303 - val_mae: 2.1999
# Epoch 55/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8788 - mae: 1.8959 - val_loss: 9.8461 - val_mae: 2.1459
# Epoch 56/100
# 11/11 [==============================] - 0s 6ms/step - loss: 6.8373 - mae: 1.8593 - val_loss: 11.2814 - val_mae: 2.3112
# Epoch 57/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8285 - mae: 1.9003 - val_loss: 9.6792 - val_mae: 2.2220
# Epoch 58/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8831 - mae: 1.8912 - val_loss: 11.4948 - val_mae: 2.2933
# Epoch 59/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.6397 - mae: 1.8516 - val_loss: 10.3192 - val_mae: 2.1817
# Epoch 60/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8301 - mae: 1.9007 - val_loss: 10.0317 - val_mae: 2.2013
# Epoch 61/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.5974 - mae: 1.8446 - val_loss: 12.0469 - val_mae: 2.3893
# Epoch 62/100
# 11/11 [==============================] - 0s 6ms/step - loss: 6.5761 - mae: 1.8095 - val_loss: 10.8496 - val_mae: 2.2634
# Epoch 63/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.3464 - mae: 1.7947 - val_loss: 10.3451 - val_mae: 2.2632
# Epoch 64/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.3100 - mae: 1.7853 - val_loss: 12.4466 - val_mae: 2.3877
# Epoch 65/100
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3893 - mae: 1.8284 - val_loss: 11.1094 - val_mae: 2.2900
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0364 - mae: 1.7519 - val_loss: 12.6884 - val_mae: 2.4499
# Epoch 67/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.0819 - mae: 1.7385 - val_loss: 10.2402 - val_mae: 2.2283
# Epoch 68/100
# 11/11 [==============================] - 0s 6ms/step - loss: 6.0534 - mae: 1.7203 - val_loss: 11.2986 - val_mae: 2.2877
# Epoch 69/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.8624 - mae: 1.7300 - val_loss: 11.9518 - val_mae: 2.3914
# Epoch 70/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.9252 - mae: 1.7280 - val_loss: 11.8739 - val_mae: 2.3804
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7591 - mae: 1.7001 - val_loss: 10.6956 - val_mae: 2.2289
# Epoch 72/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.6352 - mae: 1.6890 - val_loss: 12.6525 - val_mae: 2.4883
# Epoch 73/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.5964 - mae: 1.6878 - val_loss: 10.6484 - val_mae: 2.3178
# Epoch 74/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.6227 - mae: 1.6909 - val_loss: 12.5033 - val_mae: 2.4924
# Epoch 75/100
# 11/11 [==============================] - 0s 6ms/step - loss: 5.5162 - mae: 1.6612 - val_loss: 12.3618 - val_mae: 2.4613
# Epoch 76/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.6014 - mae: 1.6533 - val_loss: 12.9748 - val_mae: 2.5382
# Epoch 77/100
# 11/11 [==============================] - 0s 6ms/step - loss: 5.3452 - mae: 1.6518 - val_loss: 11.3262 - val_mae: 2.3588
# Epoch 78/100
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3185 - mae: 1.6437 - val_loss: 12.9641 - val_mae: 2.5251
# Epoch 79/100
# 11/11 [==============================] - 0s 7ms/step - loss: 5.2591 - mae: 1.6282 - val_loss: 12.1055 - val_mae: 2.4039
# Epoch 80/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.0503 - mae: 1.5946 - val_loss: 10.7754 - val_mae: 2.3404
# Epoch 81/100
# 11/11 [==============================] - 0s 8ms/step - loss: 5.0601 - mae: 1.5958 - val_loss: 14.6776 - val_mae: 2.7055
# Epoch 82/100
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0476 - mae: 1.5977 - val_loss: 11.4102 - val_mae: 2.3153
# Epoch 83/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.9602 - mae: 1.5886 - val_loss: 12.0627 - val_mae: 2.3890
# Epoch 84/100
# 11/11 [==============================] - 0s 7ms/step - loss: 4.8419 - mae: 1.5526 - val_loss: 12.6110 - val_mae: 2.4453
# Epoch 85/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8182 - mae: 1.5426 - val_loss: 12.6896 - val_mae: 2.4262
# Epoch 86/100
# 11/11 [==============================] - 0s 7ms/step - loss: 4.7751 - mae: 1.5580 - val_loss: 11.7513 - val_mae: 2.4045
# Epoch 87/100
# 11/11 [==============================] - 0s 7ms/step - loss: 4.8696 - mae: 1.5799 - val_loss: 12.8466 - val_mae: 2.4905
# Epoch 88/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6299 - mae: 1.5075 - val_loss: 12.7662 - val_mae: 2.5047
# Epoch 89/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.7534 - mae: 1.5331 - val_loss: 12.7965 - val_mae: 2.4534
# Epoch 90/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8485 - mae: 1.5978 - val_loss: 10.7943 - val_mae: 2.3362
# Epoch 91/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4268 - mae: 1.5131 - val_loss: 14.2249 - val_mae: 2.6133
# Epoch 92/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5081 - mae: 1.5262 - val_loss: 11.3242 - val_mae: 2.3562
# Epoch 93/100
# 11/11 [==============================] - 0s 8ms/step - loss: 4.3874 - mae: 1.5008 - val_loss: 12.9073 - val_mae: 2.4985
# Epoch 94/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4070 - mae: 1.4859 - val_loss: 13.3748 - val_mae: 2.4758
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 4.2473 - mae: 1.4778 - val_loss: 11.3721 - val_mae: 2.3350
# Epoch 96/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.1547 - mae: 1.4487 - val_loss: 13.9733 - val_mae: 2.6188
# Epoch 97/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3418 - mae: 1.5072 - val_loss: 11.6372 - val_mae: 2.3802
# Epoch 98/100
# 11/11 [==============================] - 0s 7ms/step - loss: 4.1940 - mae: 1.4679 - val_loss: 13.2309 - val_mae: 2.4935
# Epoch 99/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.1062 - mae: 1.4419 - val_loss: 13.2432 - val_mae: 2.5077
# Epoch 100/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1520 - mae: 1.4502 - val_loss: 12.1901 - val_mae: 2.3963

# %%
mse_nn, mae_nn = model.evaluate(X_test, y_test)

print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 21.4228 - mae: 2.7785
# Mean squared error on test data:  21.42284393310547
# Mean absolute error on test data:  2.7784764766693115

# %%
import sklearn
new_data = [[0.1, 10.0,5.0, 0, 0.4, 6.0, 50, 6.0, 1, 400, 20, 300, 10]]
new_data = sklearn.preprocessing.StandardScaler().fit_transform((new_data))
prediction = model.predict(new_data)
print("Predicted house price:", prediction)#11.40
# Out:
# 1/1 [==============================] - 0s 161ms/step
# Predicted house price: [[10.977672]]
